# %%
import requests
import RiotAnalyzer as Ra
from importlib import reload
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 import requests
# ----> 2 import RiotAnalyzer as Ra
#       3 from importlib import reload
#
# ModuleNotFoundError: No module named 'RiotAnalyzer'

# %%
api_key = 'RGAPI-9c72c116-9d41-4245-8af9-e431b87bf6cc'

# %%
header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9,id;q=0.8,ja;q=0.7",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": "RGAPI-9c72c116-9d41-4245-8af9-e431b87bf6cc"
}

# %%
reload(Ra)
ra = Ra.RiotAnalyzer(api_key)

# %%
leaderboard_raw = ra.get_leaderboard_raw("soloq", "d1")

# %%
top_20 = ra.get_top_20(queue="soloq", rank="d1")
top_20
# Out:
#                      tier rank      summonerName  leaguePoints  wins  losses  \
# Leaderboard Rank
# 1.0               DIAMOND    I         jumpy rat            99    66      60
# 2.0               DIAMOND    I            Corpus            94    89     101
# 3.0               DIAMOND    I      Fourgiveness            91    76      76
# 4.0               DIAMOND    I  AnotherMidderino            84    42      47
# 5.0               DIAMOND    I  monkey get funky            81    61      43
# 6.0               DIAMOND    I         bobo Xian            78    32      23
# 7.0               DIAMOND    I           Earl246            76    20      16
# 8.0               DIAMOND    I        Inumerable            75    81      83
# 8.0               DIAMOND    I           MikeHct            75    39      38
# 8.0               DIAMOND    I        CHADSTRIDE            75    44      43
# 8.0               DIAMOND    I      Juke Jouster            75    72      66
# 8.0               DIAMOND    I         ClementvZ            75    47      27
# 8.0               DIAMOND    I  elegant princess            75    28      18
# 8.0               DIAMOND    I            Kaezin            75    15      11
# 8.0               DIAMOND    I            im oom            75    84      78
# 8.0               DIAMOND    I      sNiCkYKILL3R            75    72      62
# 8.0               DIAMOND    I  wizard101warIord            75    47      38
# 8.0               DIAMOND    I     i love ashley            75    88      62
# 8.0               DIAMOND    I          Love Jax            75    36      32
# 8.0               DIAMOND    I          Cesaroxx            75    35      25
#
#                   veteran  inactive  freshBlood  hotStreak        queueType  \
# Leaderboard Rank
# 1.0                 False     False        True      False  RANKED_SOLO_5x5
# 2.0                 False     False       False      False  RANKED_SOLO_5x5
# 3.0                 False     False       False      False  RANKED_SOLO_5x5
# 4.0                 False     False       False       True  RANKED_SOLO_5x5
# 5.0                 False     False       False      False  RANKED_SOLO_5x5
# 6.0                 False     False       False      False  RANKED_SOLO_5x5
# 7.0                 False     False       False       True  RANKED_SOLO_5x5
# 8.0                 False     False       False      False  RANKED_SOLO_5x5
# 8.0                 False     False       False      False  RANKED_SOLO_5x5
# 8.0                 False     False       False      False  RANKED_SOLO_5x5
# 8.0                 False     False       False      False  RANKED_SOLO_5x5
# 8.0                 False     False       False      False  RANKED_SOLO_5x5
# 8.0                 False     False       False      False  RANKED_SOLO_5x5
# 8.0                 False     False       False       True  RANKED_SOLO_5x5
# 8.0                 False     False       False      False  RANKED_SOLO_5x5
# 8.0                 False     False       False       True  RANKED_SOLO_5x5
# 8.0                 False     False       False       True  RANKED_SOLO_5x5
# 8.0                 False     False       False      False  RANKED_SOLO_5x5
# 8.0                 False     False       False      False  RANKED_SOLO_5x5
# 8.0                 False     False       False       True  RANKED_SOLO_5x5
#
#                                                         summonerId
# Leaderboard Rank
# 1.0               iDwtwLZGybEom0xjp6rM8EePUvIhwpBFHofskXJH5ZpFK2kd
# 2.0               A7Ff8pqFp9HxzmqvHu1KO2cQjunKalxGRS63mdCUHRc-MyPl
# 3.0               alYQBQwLSa15dLMrzPvUyvAaEXInlqN60Nc40khlUd10mgVc
# 4.0               IXayxof-7UxYlgQz3cJnqsY4HXk0NUSOLf6NBOyRXHgY-4MG
# 5.0               _dI_VKBilqMUCQpIJDO628Xmg0jRKQ_GkLauNqea9UZp9dxI
# 6.0               gt9MK9mG1eJ2gUyZCKTrZBSqQgbOL_OoXKytTm-fWKqJxdE7
# 7.0               ON5Ya5i_Wkaho-6MYDbagmVBpX9wsuf0xHmgI-UYtTpvgTl_
# 8.0               5jbGAhGmKjxhARYKuRnmTA6wspsv7SMLfHcgchx8bnlvBZxm
# 8.0               4sHgjP5bNRJCLMvYoEHTBiQKZzHnjm8Td90OseNbVltS-5az
# 8.0               jUZyiiGFpv_QKeGDelsiVivxAd0jmNpzTTa61_phy54GDGgX
# 8.0               MlzFJPntLr6Ag4kXJSQB5q78DTETUis8SJlrEA3k1Kzw4lNV
# 8.0               Xge5qshBf5sjEh3Ek2t224udoiqX8PyvnpojnrRghzHWl5pN
# 8.0               hrcgKocn5j8yHOsS6tOcwBfh1yG2whWnPUM2KMcc2YRe5q3q
# 8.0               R2t4CvoiF6t-Ykc8AvgITrrkd-hKklSSmfb2uzjX45GI_fd0
# 8.0               xiObgIwz26qgiAaeUGTVwZI54nf31XV8tuFTJUDqrB0nlVMu
# 8.0               _rS5miZ7xh19qc7i6xILCk006UUBWZAxOrVGqhk1JMZqjbsQ
# 8.0               ME89V7tdvql0V7nsJgOAEG9TNWyg9gasGdB5zkSdkTL8AUvh
# 8.0               6SU1Zc4H2emhoksJWzDCpMHX4s2HDGsLJxUUrQrZ4GZf2BbE
# 8.0               kiIflsnCdj3l8hx5iNb_qM3tykxmOGPGq-9x_yCFRmM_nh0f
# 8.0               _UgmlNW0aLVfswHy2aFWSStb0BoT7t8sXRwyf8GRWjW1F56I
