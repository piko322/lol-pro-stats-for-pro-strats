# %%
df = pd.read_csv("test_alt_df.csv")
new_names = []
pro_accounts_dict = {}
for index, row in df.iterrows():
    if row['Region'] in row['Alts'].keys():
        row['Alts'][row['Region']].append(row[])
    print(row['Region'], row['Official Summoner Name'], row['Alts'])
# Out:
#   Cell In[72], line 6
#     row['Alts'][row['Region']].append(row[])
#                                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
api_key_dhil = 'RGAPI-4cc5cb0d-17ed-4196-9bcf-8f9224bad16d'
api_key_dav = 'RGAPI-b4b9b74c-58aa-4428-96ea-a9eebf17fc96'
tokens = [api_key_dhil, api_key_dav]
version = "13.17.1"
ra = Ra.RiotAnalyzer(tokens, region="NA", version=version)

# %%
df = pd.read_csv("test_alt_df.csv")
new_names = []
for name in df.get('Official Summoner Name'):
    if name in new_names:
        new_names.append(name)
type(new_names)
df
# Out:
#     Region             Team Official Summoner Name Roles Legal First Name  \
# 0       BR            FLUXO                 Baldan   NaN          Giovani
# 1       BR            FLUXO                 Forlin   NaN         Leonardo
# 2       BR            FLUXO                    Tay   NaN          Rodrigo
# 3       BR            FLUXO                Disamis   NaN            Pedro
# 4       BR            FLUXO                Ancrath   NaN          Rodrigo
# ..     ...              ...                    ...   ...              ...
# 155     BR  Vivo Keyd Stars               Mitohara   NaN            Kenzo
# 156     CN       XianTeamWE                  Demon   Top           YUEWEI
# 157     CN       XianTeamWE                   Hope   Bot              JIE
# 158     CN       XianTeamWE                 Iwandy   Sup         DINGYANG
# 159     CN       XianTeamWE                 Shanks   Mid          XIAOJUN
#
#     Legal Family Name             End Date Scrapped Roles  \
# 0              Baldan  2024-11-18 00:00:00      Top Laner
# 1             Pereira  2024-11-18 00:00:00      Top Laner
# 2              Panisa  2023-11-20 00:00:00      Top Laner
# 3          Cavalcante  2024-11-18 00:00:00        Jungler
# 4           Montrezol  2024-11-18 00:00:00        Jungler
# ..                ...                  ...            ...
# 155           Sampaio  2024-11-18 00:00:00          Coach
# 156                WU  2024-11-19 00:00:00      Bot Laner
# 157              WANG  2023-11-21 00:00:00      Mid Laner
# 158              LIAO  2023-11-21 00:00:00      Top Laner
# 159               CUI  2023-11-21 00:00:00        Support
#
#                                                   Alts
# 0                                                   {}
# 1                                                   {}
# 2    {'BR:': ['7ay', 'Esdeath', 'FPXzhaoTOP303485']...
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 155                                                 {}
# 156                                                 {}
# 157                                                 {}
# 158                                                 {}
# 159                                                 {}
#
# [160 rows x 9 columns]

# %%
len(df.get('Alts')[2])
# Out:
# 64

# %%
#For each pro, iterate through that player's accounts
for name in already_scraped:#For each account search for that account name and server, find their mastery

    for account in accounts[name]:#Add up the total mastery points for each account belonging to the player

        ra.get_mastery_by_summoner_name(account, )check uh the livechat
# Out:
#   Cell In[23], line 4
#     check uh the livechat
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import RiotAnalyzer as Ra
import ProFinder as pf

# %%
ra.get_mastery_by_summoner_name("LostRoss", "NA")
# Out:
#      championName  championLevel  championPoints  lastPlayTime  \
# Rank
# 1           Neeko              7          130678  Jul 08 23:18
# 2          Ezreal              5           51703  Aug 03 02:11
# 3            Ashe              5           48314  Jul 15 00:24
# 4           Swain              6           44314  Feb 22 14:39
# 5       Seraphine              5           33838  Jun 08 16:32
# ...           ...            ...             ...           ...
# 102       Camille              1             123  Mar 05 22:22
# 103       Vel'Koz              1             121  May 18 14:16
# 104     Gangplank              1             115  Apr 01 11:42
# 105       Orianna              1             101  Nov 08 14:02
# 106        Yorick              1              80  Apr 01 13:55
#
#             lastPlayDate percent
# Rank
# 1    2023-07-08 23:18:03  19.40%
# 2    2023-08-03 02:11:14   7.67%
# 3    2023-07-15 00:24:38   7.17%
# 4    2023-02-22 14:39:15   6.58%
# 5    2023-06-08 16:32:44   5.02%
# ...                  ...     ...
# 102  2021-03-05 22:22:59   0.02%
# 103  2022-05-18 14:16:32   0.02%
# 104  2022-04-01 11:42:01   0.02%
# 105  2021-11-08 14:02:05   0.01%
# 106  2022-04-01 13:55:24   0.01%
#
# [106 rows x 6 columns]

# %%
"""i could just add NA1 back to the regionDict if needed
it's in the class attributes for RA"""
ra
